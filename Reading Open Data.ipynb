# %%
import pandas as pd

# %%
event_data = pd.read_json("../open-data/data/events/19714.json")

# %%
# test = pd.DataFrame(columns = ['id', 'type_id', 'type_name'])

# %%
event_data.dtypes
# Out:
# id                         object
# index                       int64
# period                      int64
# timestamp          datetime64[ns]
# minute                      int64
# second                      int64
# type                       object
# possession                  int64
# possession_team            object
# play_pattern               object
# team                       object
# duration                  float64
# tactics                    object
# related_events             object
# player                     object
# position                   object
# location                   object
# pass                       object
# carry                      object
# under_pressure            float64
# ball_receipt               object
# counterpress              float64
# dribble                    object
# ball_recovery              object
# shot                       object
# goalkeeper                 object
# interception               object
# ...

# %%
event_data.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3491 entries, 0 to 3490
# Data columns (total 37 columns):
# id                 3491 non-null object
# index              3491 non-null int64
# period             3491 non-null int64
# timestamp          3491 non-null datetime64[ns]
# minute             3491 non-null int64
# second             3491 non-null int64
# type               3491 non-null object
# possession         3491 non-null int64
# possession_team    3491 non-null object
# play_pattern       3491 non-null object
# team               3491 non-null object
# duration           2632 non-null float64
# tactics            12 non-null object
# related_events     3215 non-null object
# player             3471 non-null object
# position           3471 non-null object
# location           3461 non-null object
# pass               947 non-null object
# carry              771 non-null object
# under_pressure     620 non-null float64
# ball_receipt       177 non-null object
# ...

# %%
event_data['play_pattern'][100:]
# Out:
# 100       {'id': 1, 'name': 'Regular Play'}
# 101       {'id': 1, 'name': 'Regular Play'}
# 102       {'id': 1, 'name': 'Regular Play'}
# 103       {'id': 1, 'name': 'Regular Play'}
# 104       {'id': 1, 'name': 'Regular Play'}
#                        ...
# 3486    {'id': 3, 'name': 'From Free Kick'}
# 3487    {'id': 3, 'name': 'From Free Kick'}
# 3488    {'id': 3, 'name': 'From Free Kick'}
# 3489    {'id': 3, 'name': 'From Free Kick'}
# 3490    {'id': 3, 'name': 'From Free Kick'}
# Name: play_pattern, Length: 3391, dtype: object

# %%
# column_val_types = [str(type(event_data[col][0])) for col in event_data.columns]
# [index for index,value in enumerate(column_val_types) if value == "<class 'dict'>"]
# Out:
# ["<class 'str'>",
#  "<class 'numpy.int64'>",
#  "<class 'numpy.int64'>",
#  "<class 'pandas._libs.tslibs.timestamps.Timestamp'>",
#  "<class 'numpy.int64'>",
#  "<class 'numpy.int64'>",
#  "<class 'dict'>",
#  "<class 'numpy.int64'>",
#  "<class 'dict'>",
#  "<class 'dict'>",
#  "<class 'dict'>",
#  "<class 'numpy.float64'>",
#  "<class 'dict'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'numpy.float64'>",
#  "<class 'float'>",
#  "<class 'numpy.float64'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'numpy.float64'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'float'>",
#  "<class 'numpy.float64'>",
#  "<class 'str'>"]

# %%
event_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3491 entries, 0 to 3490
# Data columns (total 37 columns):
# id                 3491 non-null object
# index              3491 non-null int64
# period             3491 non-null int64
# timestamp          3491 non-null datetime64[ns]
# minute             3491 non-null int64
# second             3491 non-null int64
# type               3491 non-null object
# possession         3491 non-null int64
# possession_team    3491 non-null object
# play_pattern       3491 non-null object
# team               3491 non-null object
# duration           2632 non-null float64
# tactics            12 non-null object
# related_events     3215 non-null object
# player             3471 non-null object
# position           3471 non-null object
# location           3461 non-null object
# pass               947 non-null object
# carry              771 non-null object
# under_pressure     620 non-null float64
# ball_receipt       177 non-null object
# ...

# %%
for i in event_data.index[:100]:
    event_data.loc[i, 'type_id'] = event_data.loc[i, 'type']['id']
    event_data.loc[i, 'type_name'] = event_data.loc[i, 'type']['name']
    event_data.loc[i, 'possession_team_id'] = event_data.loc[i, 'possession_team']['id']
    event_data.loc[i, 'possession_team_name'] = event_data.loc[i, 'possession_team']['name']
    event_data.loc[i, 'play_pattern_id'] = event_data.loc[i, 'play_pattern']['id']
    event_data.loc[i, 'play_pattern_name'] = event_data.loc[i, 'play_pattern']['name']

# %%
test_subset = event_data.iloc[:200,]

# %%
list(event_data.loc[257,'pass'].keys())
# Out:
# ['recipient',
#  'length',
#  'angle',
#  'height',
#  'end_location',
#  'cross',
#  'assisted_shot_id',
#  'shot_assist',
#  'body_part']

# %%
def get_dict_names(col):
    pass_keys = []
    for row in event_data[col]:
        if type(row) == dict:
            pass_keys.extend(list(row.keys()))
    return set(pass_keys)

# %%
get_dict_names('play_pattern')
# Out:
# {'id', 'name'}

# %%
for row in range(len(event_data)):
    print(f'ROW NUMBER: {row}')
    if type(event_data['pass'][row]) != float:
        test_dict = event_data['pass'][row]
        for i in test_dict:
            if type(test_dict[i]) == dict:
                print(f'Pass_{i}: {test_dict[i]["name"]}')
            else:
                print(f'Pass_{i}: {test_dict[i]}')
# Out:
# ROW NUMBER: 0
# ROW NUMBER: 1
# ROW NUMBER: 2
# ROW NUMBER: 3
# ROW NUMBER: 4
# Pass_recipient: Georgia Stanway
# Pass_length: 12.529964
# Pass_angle: -2.642246
# Pass_height: Ground Pass
# Pass_end_location: [50.0, 35.0]
# Pass_body_part: Left Foot
# Pass_type: Kick Off
# ROW NUMBER: 5
# ROW NUMBER: 6
# ROW NUMBER: 7
# Pass_recipient: Stephanie Houghton
# Pass_length: 28.319605
# Pass_angle: 2.306236
# Pass_height: Ground Pass
# Pass_end_location: [31.0, 52.0]
# Pass_body_part: Right Foot
# ROW NUMBER: 8
# ROW NUMBER: 9
# ROW NUMBER: 10
# Pass_recipient: Gemma Bonner
# Pass_length: 16.03122
# Pass_angle: 1.5083776
# Pass_height: Ground Pass
# Pass_end_location: [32.0, 68.0]
# Pass_body_part: Right Foot
# ROW NUMBER: 11
# ROW NUMBER: 12
# ROW NUMBER: 13
# Pass_recipient: Stephanie Houghton
# Pass_length: 16.970562
# Pass_angle: -2.3561945
# Pass_height: Ground Pass
# Pass_end_location: [24.0, 58.0]
# Pass_body_part: Right Foot
# ROW NUMBER: 14
# ROW NUMBER: 15
# ROW NUMBER: 16
# ...

# %%
test_subset['pass'][4]
# Out:
# {'recipient': {'id': 4643, 'name': 'Georgia Stanway'},
#  'length': 12.529964,
#  'angle': -2.642246,
#  'height': {'id': 1, 'name': 'Ground Pass'},
#  'end_location': [50.0, 35.0],
#  'body_part': {'id': 38, 'name': 'Left Foot'},
#  'type': {'id': 65, 'name': 'Kick Off'}}

# %%
event_data.loc[event_data['pass'].notnull(), ['pass']]
# Out:
#                                                    pass
# 4     {'recipient': {'id': 4643, 'name': 'Georgia St...
# 7     {'recipient': {'id': 10185, 'name': 'Stephanie...
# 10    {'recipient': {'id': 15554, 'name': 'Gemma Bon...
# 13    {'recipient': {'id': 10185, 'name': 'Stephanie...
# 16    {'recipient': {'id': 17524, 'name': 'Jennifer ...
# ...                                                 ...
# 3465  {'length': 47.423622, 'angle': 0.43535328, 'he...
# 3466  {'recipient': {'id': 4654, 'name': 'Nikita Par...
# 3468  {'recipient': {'id': 4659, 'name': 'Ramona Bac...
# 3474  {'recipient': {'id': 4642, 'name': 'Millie Bri...
# 3476  {'recipient': {'id': 4633, 'name': 'Magdalena ...
#
# [947 rows x 1 columns]

# %%
type(event_data['play_pattern'][0])
# Out:
# dict

# %%
# import os

# %%
# files = os.listdir('../open-data/data/events/')

# full_df = pd.concat([pd.read_json(f'../open-data/data/events/{file}') for file in files], sort = False, ignore_index = True)

# %% [markdown]
# ### PETER IT WORKED!!!

# %%
# full_df.isna().sum()

# %%
# full_df['team_name'] = [i['name'] for i in full_df['team']]
# full_df['team_name']

# %%
# full_df.info()

# %%
# full_df['dribble'].value_counts()

# %%
# for team in full_df['team'].unique():
#     print(team)
#     print(team['name'])
#     #full_df.loc[full_df['team']==team,:].reset_index(drop = True).to_csv(f'{team["name"]}.csv')

# %%
# full_df[full_df['team'] == {'id': 974, 'name': 'Reading WFC'}]

# %%
# full_df.head().T

# %%
# lineups_data = pd.read_json("../open-data/data/lineups/19714.json")

# %%
# lineups_data.info()

# %%
# lineups_data #How do I look at the entire list?

# %%
# type(lineups_data)

# %%
# lineups_data["lineup"][0]
