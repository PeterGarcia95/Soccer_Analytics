# %%
import pandas as pd

# %%
event_data = pd.read_json("../open-data/data/events/19714.json")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3491 entries, 0 to 3490
# Data columns (total 35 columns):
# id                 3491 non-null object
# index              3491 non-null int64
# period             3491 non-null int64
# timestamp          3491 non-null datetime64[ns]
# minute             3491 non-null int64
# second             3491 non-null int64
# type               3491 non-null object
# possession         3491 non-null int64
# possession_team    3491 non-null object
# play_pattern       3491 non-null object
# team               3491 non-null object
# duration           2632 non-null float64
# tactics            12 non-null object
# related_events     3215 non-null object
# player             3471 non-null object
# position           3471 non-null object
# location           3461 non-null object
# pass               947 non-null object
# carry              771 non-null object
# under_pressure     620 non-null float64
# ball_receipt       177 non-null object
# counterpress       127 non-null float64
# dribble            26 non-null object
# ball_recovery      8 non-null object
# shot               31 non-null object
# goalkeeper         35 non-null object
# interception       18 non-null object
# foul_committed     6 non-null object
# duel               51 non-null object
# 50_50              4 non-null object
# off_camera         43 non-null float64
# foul_won           3 non-null object
# substitution       6 non-null object
# block              2 non-null object
# clearance          1 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(25)
# memory usage: 954.7+ KB

# %%
data.loc[224,'play_pattern']
# Out:
# {'id': 4, 'name': 'From Throw In'}

# %%
import os

# %%
files = os.listdir('../open-data/data/events/')

full_df = pd.concat([pd.read_json(f'../open-data/data/events/{file}') for file in files], sort = False, ignore_index = True)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### PETER IT WORKED!!!

# %%
full_df.isna().sum()
# Out:
# 50_50              2273213
# bad_behaviour      2273827
# ball_receipt       2183603
# ball_recovery      2268734
# block              2273106
# carry              1757395
# clearance          2251387
# counterpress       2203669
# dribble            2247325
# duel               2233492
# duration            613512
# foul_committed     2268472
# foul_won           2267366
# goalkeeper         2255041
# half_end           2274234
# half_start         2274216
# id                       0
# index                    0
# injury_stoppage    2273980
# interception       2261878
# location             17729
# minute                   0
# miscontrol         2273612
# off_camera         2248411
# out                2260660
# pass               1647990
# period                   0
# play_pattern             0
# player               11739
# player_off         2274236
# position             11739
# possession               0
# possession_team          0
# related_events       99218
# second                   0
# shot               2258061
# substitution       2270717
# tactics            2271850
# team                     0
# timestamp                0
# type                     0
# under_pressure     1786349
# dtype: int64

# %%
full_df['team_name'] = [i['name'] for i in full_df['team']]
full_df['team_name']
# Out:
# 0                  Reading WFC
# 1          West Ham United LFC
# 2                  Reading WFC
# 3          West Ham United LFC
# 4                  Reading WFC
#                   ...
# 2274237               Portugal
# 2274238               Portugal
# 2274239                  Spain
# 2274240                  Spain
# 2274241               Portugal
# Name: team_name, Length: 2274242, dtype: object

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2274242 entries, 0 to 2274241
# Data columns (total 42 columns):
# 50_50              object
# bad_behaviour      object
# ball_receipt       object
# ball_recovery      object
# block              object
# carry              object
# clearance          object
# counterpress       float64
# dribble            object
# duel               object
# duration           float64
# foul_committed     object
# foul_won           object
# goalkeeper         object
# half_end           object
# half_start         object
# id                 object
# index              int64
# injury_stoppage    object
# interception       object
# location           object
# minute             int64
# miscontrol         object
# off_camera         object
# out                float64
# pass               object
# period             int64
# play_pattern       object
# player             object
# player_off         object
# position           object
# possession         int64
# possession_team    object
# related_events     object
# second             int64
# shot               object
# substitution       object
# tactics            object
# team               object
# timestamp          datetime64[ns]
# type               object
# under_pressure     float64
# dtypes: datetime64[ns](1), float64(4), int64(5), object(32)
# memory usage: 728.7+ MB

# %%
full_df['dribble'].value_counts()
# Out:
# {'outcome': {'id': 8, 'name': 'Complete'}}                                         15795
# {'outcome': {'id': 9, 'name': 'Incomplete'}}                                        8721
# {'overrun': True, 'outcome': {'id': 9, 'name': 'Incomplete'}}                       1236
# {'nutmeg': True, 'outcome': {'id': 8, 'name': 'Complete'}}                           588
# {'overrun': True, 'outcome': {'id': 8, 'name': 'Complete'}}                          212
# {'outcome': {'id': 9, 'name': 'Incomplete'}, 'nutmeg': True}                         136
# {'outcome': {'id': 9, 'name': 'Incomplete'}, 'overrun': True, 'nutmeg': True}        132
# {'outcome': {'id': 8, 'name': 'Complete'}, 'no_touch': True}                          48
# {'outcome': {'id': 8, 'name': 'Complete'}, 'overrun': True, 'nutmeg': True}           30
# {'outcome': {'id': 9, 'name': 'Incomplete'}, 'no_touch': True}                        15
# {'outcome': {'id': 9, 'name': 'Incomplete'}, 'overrun': True, 'no_touch': True}        2
# {'outcome': {'id': 8, 'name': 'Complete'}, 'nutmeg': True, 'no_touch': True}           1
# {'no_touch': True, 'outcome': {'id': 8, 'name': 'Complete'}, 'overrun': True}          1
# Name: dribble, dtype: int64

# %%
for team in full_df['team'].unique():
    print(team)
    print(team['name'])
    #full_df.loc[full_df['team']==team,:].reset_index(drop = True).to_csv(f'{team["name"]}.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-9753fbe3c941> in <module>
# ----> 1 for team in full_df['team'].unique():
#       2     print(team)
#       3     print(team['name'])
#       4     #full_df.loc[full_df['team']==team,:].reset_index(drop = True).to_csv(f'{team["name"]}.csv')
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/series.py in unique(self)
#    1986         Categories (3, object): [a < b < c]
#    1987         """
# -> 1988         result = super().unique()
#    1989         return result
#    1990
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/base.py in unique(self)
#    1403             from pandas.core.algorithms import unique1d
#    1404
# -> 1405             result = unique1d(values)
#    1406
#    1407         return result
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in unique(values)
#     403
#     404     table = htable(len(values))
# --> 405     uniques = table.unique(values)
#     406     uniques = _reconstruct_data(uniques, dtype, original)
#     407     return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'dict'

# %%
full_df[full_df['team'] == {'id': 974, 'name': 'Reading WFC'}]
# Out:
#         50_50 bad_behaviour ball_receipt ball_recovery block  \
# 0         NaN           NaN          NaN           NaN   NaN
# 2         NaN           NaN          NaN           NaN   NaN
# 4         NaN           NaN          NaN           NaN   NaN
# 5         NaN           NaN          NaN           NaN   NaN
# 6         NaN           NaN          NaN           NaN   NaN
# ...       ...           ...          ...           ...   ...
# 2142997   NaN           NaN          NaN           NaN   NaN
# 2142998   NaN           NaN          NaN           NaN   NaN
# 2142999   NaN           NaN          NaN           NaN   NaN
# 2143000   NaN           NaN          NaN           NaN   NaN
# 2143001   NaN           NaN          NaN           NaN   NaN
#
#                                   carry clearance  counterpress dribble duel  \
# 0                                   NaN       NaN           NaN     NaN  NaN
# 2                                   NaN       NaN           NaN     NaN  NaN
# 4                                   NaN       NaN           NaN     NaN  NaN
# 5                                   NaN       NaN           NaN     NaN  NaN
# 6        {'end_location': [46.0, 36.0]}       NaN           NaN     NaN  NaN
# ...                                 ...       ...           ...     ...  ...
# 2142997                             NaN       NaN           NaN     NaN  NaN
# 2142998                             NaN       NaN           NaN     NaN  NaN
# 2142999                             NaN       NaN           NaN     NaN  NaN
# 2143000                             NaN       NaN           NaN     NaN  NaN
# 2143001                             NaN       NaN           NaN     NaN  NaN
#
#          ...                     possession_team  \
# 0        ...  {'id': 974, 'name': 'Reading WFC'}
# 2        ...  {'id': 974, 'name': 'Reading WFC'}
# 4        ...  {'id': 974, 'name': 'Reading WFC'}
# 5        ...  {'id': 974, 'name': 'Reading WFC'}
# 6        ...  {'id': 974, 'name': 'Reading WFC'}
# ...      ...                                 ...
# 2142997  ...  {'id': 974, 'name': 'Reading WFC'}
# 2142998  ...  {'id': 974, 'name': 'Reading WFC'}
# 2142999  ...  {'id': 974, 'name': 'Reading WFC'}
# 2143000  ...  {'id': 974, 'name': 'Reading WFC'}
# 2143001  ...  {'id': 974, 'name': 'Reading WFC'}
#
#                                             related_events second shot  \
# 0                                                      NaN      0  NaN
# 2                   [503d06c8-5441-43b3-9aa5-7ea68ecabad2]      0  NaN
# 4                   [e39d5015-8ff8-429e-949f-a7d27bfd8de5]      0  NaN
# 5                   [4b92ae51-2702-4d07-a9e3-848fa1170cb3]      1  NaN
# 6        [345f91f2-9e62-4558-8e57-b00190a5e072, e39d501...      1  NaN
# ...                                                    ...    ...  ...
# 2142997  [1d95f0d3-0370-4ed1-bf9e-a1b3236216a9, a936fbf...     32  NaN
# 2142998             [013c13a7-5036-4d58-99d0-bee87c4d669b]     33  NaN
# 2142999             [3689400d-073e-49b2-83d8-c6a8cc0b805f]     33  NaN
# 2143000             [d5fb7187-3cc5-4495-b859-5b0dde1637bf]     34  NaN
# 2143001             [43cba533-ed08-46d8-920a-9cbb74d793f2]     34  NaN
#
#         substitution                                            tactics  \
# 0                NaN  {'formation': 4222, 'lineup': [{'player': {'id...
# 2                NaN                                                NaN
# 4                NaN                                                NaN
# 5                NaN                                                NaN
# 6                NaN                                                NaN
# ...              ...                                                ...
# 2142997          NaN                                                NaN
# 2142998          NaN                                                NaN
# 2142999          NaN                                                NaN
# 2143000          NaN                                                NaN
# 2143001          NaN                                                NaN
#
#                                        team               timestamp  \
# 0        {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:00:00.000
# 2        {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:00:00.000
# 4        {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:00:00.080
# 5        {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:00:01.812
# 6        {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:00:01.812
# ...                                     ...                     ...
# 2142997  {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:49:32.085
# 2142998  {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:49:33.485
# 2142999  {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:49:33.485
# 2143000  {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:49:34.767
# 2143001  {'id': 974, 'name': 'Reading WFC'} 2019-11-20 00:49:34.872
#
#                                         type under_pressure
# 0          {'id': 35, 'name': 'Starting XI'}            NaN
# 2           {'id': 18, 'name': 'Half Start'}            NaN
# 4                 {'id': 30, 'name': 'Pass'}            NaN
# 5        {'id': 42, 'name': 'Ball Receipt*'}            NaN
# 6                {'id': 43, 'name': 'Carry'}            NaN
# ...                                      ...            ...
# 2142997           {'id': 30, 'name': 'Pass'}            1.0
# 2142998  {'id': 42, 'name': 'Ball Receipt*'}            NaN
# 2142999           {'id': 30, 'name': 'Pass'}            NaN
# 2143000  {'id': 42, 'name': 'Ball Receipt*'}            NaN
# 2143001       {'id': 34, 'name': 'Half End'}            NaN
#
# [40949 rows x 42 columns]

# %%
full_df.head().T
# Out:
#                                                                  0  \
# 50_50                                                          NaN
# bad_behaviour                                                  NaN
# ball_receipt                                                   NaN
# ball_recovery                                                  NaN
# block                                                          NaN
# carry                                                          NaN
# clearance                                                      NaN
# counterpress                                                   NaN
# dribble                                                        NaN
# duel                                                           NaN
# duration                                                         0
# foul_committed                                                 NaN
# foul_won                                                       NaN
# goalkeeper                                                     NaN
# half_end                                                       NaN
# half_start                                                     NaN
# id                            92f7b2d2-d048-4bbc-b8ff-67dcfc328fb2
# index                                                            1
# injury_stoppage                                                NaN
# interception                                                   NaN
# location                                                       NaN
# minute                                                           0
# miscontrol                                                     NaN
# off_camera                                                     NaN
# out                                                            NaN
# pass                                                           NaN
# period                                                           1
# play_pattern                     {'id': 1, 'name': 'Regular Play'}
# player                                                         NaN
# player_off                                                     NaN
# position                                                       NaN
# possession                                                       1
# possession_team                 {'id': 974, 'name': 'Reading WFC'}
# related_events                                                 NaN
# second                                                           0
# shot                                                           NaN
# substitution                                                   NaN
# tactics          {'formation': 4222, 'lineup': [{'player': {'id...
# team                            {'id': 974, 'name': 'Reading WFC'}
# timestamp                                      2019-11-20 00:00:00
# type                             {'id': 35, 'name': 'Starting XI'}
# under_pressure                                                 NaN
#
#                                                                  1  \
# 50_50                                                          NaN
# bad_behaviour                                                  NaN
# ball_receipt                                                   NaN
# ball_recovery                                                  NaN
# block                                                          NaN
# carry                                                          NaN
# clearance                                                      NaN
# counterpress                                                   NaN
# dribble                                                        NaN
# duel                                                           NaN
# duration                                                         0
# foul_committed                                                 NaN
# foul_won                                                       NaN
# goalkeeper                                                     NaN
# half_end                                                       NaN
# half_start                                                     NaN
# id                            e61277b1-87a1-40e5-becc-dd727c821920
# index                                                            2
# injury_stoppage                                                NaN
# interception                                                   NaN
# location                                                       NaN
# minute                                                           0
# miscontrol                                                     NaN
# off_camera                                                     NaN
# out                                                            NaN
# pass                                                           NaN
# period                                                           1
# play_pattern                     {'id': 1, 'name': 'Regular Play'}
# player                                                         NaN
# player_off                                                     NaN
# position                                                       NaN
# possession                                                       1
# possession_team                 {'id': 974, 'name': 'Reading WFC'}
# related_events                                                 NaN
# second                                                           0
# shot                                                           NaN
# substitution                                                   NaN
# tactics          {'formation': 41221, 'lineup': [{'player': {'i...
# team                    {'id': 972, 'name': 'West Ham United LFC'}
# timestamp                                      2019-11-20 00:00:00
# type                             {'id': 35, 'name': 'Starting XI'}
# under_pressure                                                 NaN
#
#                                                       2  \
# 50_50                                               NaN
# bad_behaviour                                       NaN
# ball_receipt                                        NaN
# ball_recovery                                       NaN
# block                                               NaN
# carry                                               NaN
# clearance                                           NaN
# counterpress                                        NaN
# dribble                                             NaN
# duel                                                NaN
# duration                                              0
# foul_committed                                      NaN
# foul_won                                            NaN
# goalkeeper                                          NaN
# half_end                                            NaN
# half_start                                          NaN
# id                 bfcb5195-fef1-4078-b76a-2240dcdb78d7
# index                                                 3
# injury_stoppage                                     NaN
# interception                                        NaN
# location                                            NaN
# minute                                                0
# miscontrol                                          NaN
# off_camera                                          NaN
# out                                                 NaN
# pass                                                NaN
# period                                                1
# play_pattern          {'id': 1, 'name': 'Regular Play'}
# player                                              NaN
# player_off                                          NaN
# position                                            NaN
# possession                                            1
# possession_team      {'id': 974, 'name': 'Reading WFC'}
# related_events   [503d06c8-5441-43b3-9aa5-7ea68ecabad2]
# second                                                0
# shot                                                NaN
# substitution                                        NaN
# tactics                                             NaN
# team                 {'id': 974, 'name': 'Reading WFC'}
# timestamp                           2019-11-20 00:00:00
# type                   {'id': 18, 'name': 'Half Start'}
# under_pressure                                      NaN
#
#                                                           3  \
# 50_50                                                   NaN
# bad_behaviour                                           NaN
# ball_receipt                                            NaN
# ball_recovery                                           NaN
# block                                                   NaN
# carry                                                   NaN
# clearance                                               NaN
# counterpress                                            NaN
# dribble                                                 NaN
# duel                                                    NaN
# duration                                                  0
# foul_committed                                          NaN
# foul_won                                                NaN
# goalkeeper                                              NaN
# half_end                                                NaN
# half_start                                              NaN
# id                     503d06c8-5441-43b3-9aa5-7ea68ecabad2
# index                                                     4
# injury_stoppage                                         NaN
# interception                                            NaN
# location                                                NaN
# minute                                                    0
# miscontrol                                              NaN
# off_camera                                              NaN
# out                                                     NaN
# pass                                                    NaN
# period                                                    1
# play_pattern              {'id': 1, 'name': 'Regular Play'}
# player                                                  NaN
# player_off                                              NaN
# position                                                NaN
# possession                                                1
# possession_team          {'id': 974, 'name': 'Reading WFC'}
# related_events       [bfcb5195-fef1-4078-b76a-2240dcdb78d7]
# second                                                    0
# shot                                                    NaN
# substitution                                            NaN
# tactics                                                 NaN
# team             {'id': 972, 'name': 'West Ham United LFC'}
# timestamp                               2019-11-20 00:00:00
# type                       {'id': 18, 'name': 'Half Start'}
# under_pressure                                          NaN
#
#                                                                  4
# 50_50                                                          NaN
# bad_behaviour                                                  NaN
# ball_receipt                                                   NaN
# ball_recovery                                                  NaN
# block                                                          NaN
# carry                                                          NaN
# clearance                                                      NaN
# counterpress                                                   NaN
# dribble                                                        NaN
# duel                                                           NaN
# duration                                                    1.7322
# foul_committed                                                 NaN
# foul_won                                                       NaN
# goalkeeper                                                     NaN
# half_end                                                       NaN
# half_start                                                     NaN
# id                            4b92ae51-2702-4d07-a9e3-848fa1170cb3
# index                                                            5
# injury_stoppage                                                NaN
# interception                                                   NaN
# location                                              [60.0, 40.0]
# minute                                                           0
# miscontrol                                                     NaN
# off_camera                                                     NaN
# out                                                            NaN
# pass             {'recipient': {'id': 10198, 'name': 'Josanne P...
# period                                                           1
# play_pattern                    {'id': 9, 'name': 'From Kick Off'}
# player                      {'id': 10251, 'name': 'Fara Williams'}
# player_off                                                     NaN
# position             {'id': 11, 'name': 'Left Defensive Midfield'}
# possession                                                       2
# possession_team                 {'id': 974, 'name': 'Reading WFC'}
# related_events              [e39d5015-8ff8-429e-949f-a7d27bfd8de5]
# second                                                           0
# shot                                                           NaN
# substitution                                                   NaN
# tactics                                                        NaN
# team                            {'id': 974, 'name': 'Reading WFC'}
# timestamp                               2019-11-20 00:00:00.080000
# type                                    {'id': 30, 'name': 'Pass'}
# under_pressure                                                 NaN

# %%
lineups_data = pd.read_json("../open-data/data/lineups/19714.json")

# %%
lineups_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
# team_id      2 non-null int64
# team_name    2 non-null object
# lineup       2 non-null object
# dtypes: int64(1), object(2)
# memory usage: 176.0+ bytes

# %%
lineups_data #How do I look at the entire list?
# Out:
#    team_id            team_name  \
# 0      971          Chelsea FCW
# 1      746  Manchester City WFC
#
#                                               lineup
# 0  [{'player_id': 4633, 'player_name': 'Magdalena...
# 1  [{'player_id': 4643, 'player_name': 'Georgia S...

# %%
type(lineups_data)
# Out:
# pandas.core.frame.DataFrame

# %%
lineups_data["lineup"][0]
# Out:
# [{'player_id': 4633,
#   'player_name': 'Magdalena Ericsson',
#   'player_nickname': None,
#   'jersey_number': 16,
#   'country': {'id': 220, 'name': 'Sweden'}},
#  {'player_id': 4638,
#   'player_name': 'Drew Spence',
#   'player_nickname': None,
#   'jersey_number': 24,
#   'country': {'id': 68, 'name': 'England'}},
#  {'player_id': 4640,
#   'player_name': 'Rut Hedvig Lindahl',
#   'player_nickname': 'Hedvig Lindahl',
#   'jersey_number': 1,
#   'country': {'id': 220, 'name': 'Sweden'}},
#  {'player_id': 4641,
#   'player_name': 'Francesca Kirby',
#   'player_nickname': None,
#   'jersey_number': 14,
#   'country': {'id': 68, 'name': 'England'}},
#  {'player_id': 4642,
#   'player_name': 'Millie Bright',
#   'player_nickname': None,
#   'jersey_number': 4,
#   'country': {'id': 68, 'name': 'England'}},
#  {'player_id': 4647,
#   'player_name': 'So-yun Ji',
#   'player_nickname': 'Ji So-yun',
#   'jersey_number': 10,
#   'country': {'id': 121, 'name': 'Korea\xa0(South)'}},
#  {'player_id': 4659,
#   'player_name': 'Ramona Bachmann',
#   'player_nickname': None,
#   'jersey_number': 23,
#   'country': {'id': 221, 'name': 'Switzerland'}},
#  {'player_id': 4660,
#   'player_name': 'Erin Cuthbert',
#   'player_nickname': None,
#   'jersey_number': 22,
#   'country': {'id': 201, 'name': 'Scotland'}},
#  {'player_id': 10222,
#   'player_name': 'Jonna Andersson',
#   'player_nickname': None,
#   'jersey_number': 20,
#   'country': {'id': 220, 'name': 'Sweden'}},
#  {'player_id': 10395,
#   'player_name': 'Maren Nævdal Mjelde',
#   'player_nickname': 'Maren Mjelde',
#   'jersey_number': 18,
#   'country': {'id': 171, 'name': 'Norway'}},
#  {'player_id': 15549,
#   'player_name': 'Sophie Ingle',
#   'player_nickname': None,
#   'jersey_number': 5,
#   'country': {'id': 249, 'name': 'Wales'}},
#  {'player_id': 15550,
#   'player_name': 'Bethany England',
#   'player_nickname': None,
#   'jersey_number': 15,
#   'country': {'id': 68, 'name': 'England'}},
#  {'player_id': 15553,
#   'player_name': 'Karen Julia Carney',
#   'player_nickname': None,
#   'jersey_number': 8,
#   'country': {'id': 68, 'name': 'England'}},
#  {'player_id': 19422,
#   'player_name': 'Jessica Carter',
#   'player_nickname': None,
#   'jersey_number': 7,
#   'country': {'id': 68, 'name': 'England'}}]
